# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("data_clean.csv")
data

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  158 non-null    int64
#  1   Ozone       120 non-null    float64
#  2   Solar.R     151 non-null    float64
#  3   Wind        158 non-null    float64
#  4   Temp C      158 non-null    object
#  5   Month       158 non-null    object
#  6   Day         158 non-null    int64
#  7   Year        158 non-null    int64
#  8   Temp        158 non-null    int64
#  9   Weather     155 non-null    object
# dtypes: float64(3), int64(4), object(3)
# memory usage: 12.5+ KB

# %%
print(type(data))
print(data.shape)
print(data.size)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# (158, 10)
# 1580

# %%
data1 = data.drop(['Unnamed: 0',"Temp C"], axis =1)
data1
# Out:
#      Ozone  Solar.R  Wind Month  Day  Year  Temp Weather
# 0     41.0    190.0   7.4     5    1  2010    67       S
# 1     36.0    118.0   8.0     5    2  2010    72       C
# 2     12.0    149.0  12.6     5    3  2010    74      PS
# 3     18.0    313.0  11.5     5    4  2010    62       S
# 4      NaN      NaN  14.3     5    5  2010    56       S
# ..     ...      ...   ...   ...  ...   ...   ...     ...
# 153   41.0    190.0   7.4     5    1  2010    67       C
# 154   30.0    193.0   6.9     9   26  2010    70      PS
# 155    NaN    145.0  13.2     9   27  2010    77       S
# 156   14.0    191.0  14.3     9   28  2010    75       S
# 157   18.0    131.0   8.0     9   29  2010    76       C
#
# [158 rows x 8 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  158 non-null    int64
#  1   Ozone       120 non-null    float64
#  2   Solar.R     151 non-null    float64
#  3   Wind        158 non-null    float64
#  4   Temp C      158 non-null    object
#  5   Month       158 non-null    object
#  6   Day         158 non-null    int64
#  7   Year        158 non-null    int64
#  8   Temp        158 non-null    int64
#  9   Weather     155 non-null    object
# dtypes: float64(3), int64(4), object(3)
# memory usage: 12.5+ KB

# %%
data1['Month']=pd.to_numeric(data['Month'],errors='coerce')
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Ozone    120 non-null    float64
#  1   Solar.R  151 non-null    float64
#  2   Wind     158 non-null    float64
#  3   Month    157 non-null    float64
#  4   Day      158 non-null    int64
#  5   Year     158 non-null    int64
#  6   Temp     158 non-null    int64
#  7   Weather  155 non-null    object
# dtypes: float64(4), int64(3), object(1)
# memory usage: 10.0+ KB

# %%
data1[data1.duplicated(keep = False)]
# Out:
#      Ozone  Solar.R  Wind  Month  Day  Year  Temp Weather
# 150   14.0    191.0  14.3    9.0   28  2010    75       S
# 156   14.0    191.0  14.3    9.0   28  2010    75       S

# %%
data1.drop_duplicates(keep='first',inplace=True)
data1
# Out:
#      Ozone  Solar.R  Wind  Month  Day  Year  Temp Weather
# 0     41.0    190.0   7.4    5.0    1  2010    67       S
# 1     36.0    118.0   8.0    5.0    2  2010    72       C
# 2     12.0    149.0  12.6    5.0    3  2010    74      PS
# 3     18.0    313.0  11.5    5.0    4  2010    62       S
# 4      NaN      NaN  14.3    5.0    5  2010    56       S
# ..     ...      ...   ...    ...  ...   ...   ...     ...
# 152   20.0    223.0  11.5    9.0   30  2010    68       S
# 153   41.0    190.0   7.4    5.0    1  2010    67       C
# 154   30.0    193.0   6.9    9.0   26  2010    70      PS
# 155    NaN    145.0  13.2    9.0   27  2010    77       S
# 157   18.0    131.0   8.0    9.0   29  2010    76       C
#
# [157 rows x 8 columns]

# %%
data1.rename({'Wind':'winds'},axis=1,inplace=True)
data1
# Out:
#      Ozone  Solar.R  winds  Month  Day  Year  Temp Weather
# 0     41.0    190.0    7.4    5.0    1  2010    67       S
# 1     36.0    118.0    8.0    5.0    2  2010    72       C
# 2     12.0    149.0   12.6    5.0    3  2010    74      PS
# 3     18.0    313.0   11.5    5.0    4  2010    62       S
# 4      NaN      NaN   14.3    5.0    5  2010    56       S
# ..     ...      ...    ...    ...  ...   ...   ...     ...
# 152   20.0    223.0   11.5    9.0   30  2010    68       S
# 153   41.0    190.0    7.4    5.0    1  2010    67       C
# 154   30.0    193.0    6.9    9.0   26  2010    70      PS
# 155    NaN    145.0   13.2    9.0   27  2010    77       S
# 157   18.0    131.0    8.0    9.0   29  2010    76       C
#
# [157 rows x 8 columns]

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 157 entries, 0 to 157
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Ozone    119 non-null    float64
#  1   Solar.R  150 non-null    float64
#  2   winds    157 non-null    float64
#  3   Month    156 non-null    float64
#  4   Day      157 non-null    int64
#  5   Year     157 non-null    int64
#  6   Temp     157 non-null    int64
#  7   Weather  154 non-null    object
# dtypes: float64(4), int64(3), object(1)
# memory usage: 11.0+ KB

# %%
data1.isnull().sum()
# Out:
# Ozone      38
# Solar.R     7
# winds       0
# Month       1
# Day         0
# Year        0
# Temp        0
# Weather     3
# dtype: int64

# %%
cols=data1.columns
colors1=['Green','Black']
sns.heatmap(data1[cols].isnull(),cmap=sns.color_palette(colors1),cbar=True)
# Out:
# <Axes: >

# %%
median_ozone=data1["Solar"].median()
mean_ozone=data1["Ozone"].mean()
print("Median of Solar:",median_ozone)
print("Mean of Ozone:",mean_ozone)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Solar'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 median_ozone=data1["Solar"].median()
#       2 mean_ozone=data1["Ozone"].mean()
#       3 print("Median of Solar:",median_ozone)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'Solar'

# %%
data1['Ozone']=data1['Ozone'].fillna(median_ozone)
data1.isnull().sum()

# %%
median_ozone=data1["Solar"].median()
mean_ozone=data1["Solar"].mean()
print("Median of Sloar:",median_ozone)
print("Mean of Sloar:",mean_ozone)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Solar'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 median_ozone=data1["Solar"].median()
#       2 mean_ozone=data1["Solar"].mean()
#       3 print("Median of Sloar:",median_ozone)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'Solar'

# %%
print(data1["Weather"].value_counts())
mode_weather=data1["Weather"].mode()[0]
print(mode_weather)
# Out:
# Weather
# S     58
# C     49
# PS    47
# Name: count, dtype: int64
# S

# %%
##detection of outlers in the columns
fig,axes=plt.subplots(2,1,figsize=(8,6),gridspec_kw={'height_ratios':[1,3]})
sns.boxplot(data=data1["Ozone"],ax=axes[0],color='Red',width=0.5,orient='h')
axes[0].set_title("Boxplot")
axes[0].set_xlabel("Ozone Levels")
sns.histplot(data1["Ozone"],kde=True,ax=axes[1],color='Green',bins=30)
axes[1].set_title("Histogram with KDE")
axes[1].set_xlabel("Ozone Levels")
axes[1].set_ylabel("Frequency")
plt.tight_layout()
plt.show()

# %%
##detection of outlers in the columns
fig,axes=plt.subplots(2,1,figsize=(8,6),gridspec_kw={'height_ratios':[1,3]})
sns.boxplot(data=data1["Ozone"],ax=axes[0],color='Red',width=0.5,orient='h')
axes[0].set_title("Boxplot")
axes[0].set_xlabel("Weather Levels")
sns.histplot(data1["Ozone"],kde=True,ax=axes[1],color='Green',bins=30)
axes[1].set_title("Histogram with KDE")
axes[1].set_xlabel("Ozone Levels")
axes[1].set_ylabel("Frequency")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(6,2))
plt.boxplot(data1["Ozone"],vert=False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x23cde40a7e0>,
#   <matplotlib.lines.Line2D at 0x23cde139f40>],
#  'caps': [<matplotlib.lines.Line2D at 0x23cde1385f0>,
#   <matplotlib.lines.Line2D at 0x23cde13a3f0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x23cde139ac0>],
#  'medians': [<matplotlib.lines.Line2D at 0x23cde13a6c0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x23cde13a990>],
#  'means': []}

# %%
plt.figure(figsize=(6,2))
boxplot_data=plt.boxplot(data1["Ozone"],vert=False)
[item.get_xdata() for item in boxplot_data['fliers']]
# Out:
# [array([], dtype=float64)]

# %%
data1["Ozone"].describe()
# Out:
# count    119.000000
# mean      41.815126
# std       32.659249
# min        1.000000
# 25%       18.000000
# 50%       31.000000
# 75%       62.000000
# max      168.000000
# Name: Ozone, dtype: float64

# %%
mu=data1["Ozone"].describe()[1]
sigma=data1["Ozone"].describe()[2]
for x in data1["Ozone"]:
    if((x<(mu-3*sigma)) or (x>(mu+3*sigma))):
        print(x)
# Out:
# 168.0
# C:\Users\bicha\AppData\Local\Temp\ipykernel_5352\2479272794.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   mu=data1["Ozone"].describe()[1]
# C:\Users\bicha\AppData\Local\Temp\ipykernel_5352\2479272794.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   sigma=data1["Ozone"].describe()[2]

# %%
import scipy.stats as stats

plt.figure(figsize=(8,6))
stats.probplot(data1["Ozone"],dist="norm",plot=plt)
plt.title("Q-Q plot for outlier Detection",fontsize=14)
plt.xlabel("Theoretical Quantiles",fontsize=12)
# Out:
# Text(0.5, 0, 'Theoretical Quantiles')

# %% [markdown]
# ##oservations from Q-Q plot

# %%
sns.violinplot(data=data1["Ozone"],color='lightgreen')
plt.title("Violin plot")
# Out:
# Text(0.5, 1.0, 'Violin plot')

# %%
sns.swarmplot(data=data1,x="Weather",y="Ozone",color="orange",palette="Set2",size=6)
# Out:
# C:\Users\bicha\AppData\Local\Temp\ipykernel_5352\1590678044.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.swarmplot(data=data1,x="Weather",y="Ozone",color="orange",palette="Set2",size=6)
# <Axes: xlabel='Weather', ylabel='Ozone'>

# %%
sns.striplot(data=data1,x="Weather",y="Ozone",color="orange",palette="Set1',size=6,jitter=True)
# Out:
#   Cell In[67], line 1
#     sns.striplot(data=data1,x="Weather",y="Ozone",color="orange",palette="Set1',size=6,jitter=True)
#                                                                          ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
sns.kdeplot(data=data1["Ozone"],fill=True,color="blue")
sns.rugplot(data=data1["Ozone"],color="black")
# Out:
# <Axes: xlabel='Ozone', ylabel='Density'>

# %%
sns.boxplot(data = data1, x= "Weather" ,y= "Ozone")
# Out:
# <Axes: xlabel='Weather', ylabel='Ozone'>

# %% [markdown]
# Correlation coeffecient pair plots

# %%
plt.scatter(data1["winds"],data1["Temp"])

# %%
data1["winds"].corr(data1["Temp"])
# Out:
# -0.44122806925588215

# %%
## read all numeric (float) columns into a new table data1_numeric
data1_numeric =data.iloc[:,[0,1,2,6]]
data1_numeric
# Out:
#      Unnamed: 0  Ozone  Solar.R  Day
# 0             1   41.0    190.0    1
# 1             2   36.0    118.0    2
# 2             3   12.0    149.0    3
# 3             4   18.0    313.0    4
# 4             5    NaN      NaN    5
# ..          ...    ...      ...  ...
# 153         154   41.0    190.0    1
# 154         155   30.0    193.0   26
# 155         156    NaN    145.0   27
# 156         157   14.0    191.0   28
# 157         158   18.0    131.0   29
#
# [158 rows x 4 columns]

# %%
data1_numeric=data1.iloc[:,[0,1,2,6]]
data1_numeric
# Out:
#      Ozone  Solar.R  winds  Temp
# 0     41.0    190.0    7.4    67
# 1     36.0    118.0    8.0    72
# 2     12.0    149.0   12.6    74
# 3     18.0    313.0   11.5    62
# 4      NaN      NaN   14.3    56
# ..     ...      ...    ...   ...
# 152   20.0    223.0   11.5    68
# 153   41.0    190.0    7.4    67
# 154   30.0    193.0    6.9    70
# 155    NaN    145.0   13.2    77
# 157   18.0    131.0    8.0    76
#
# [157 rows x 4 columns]

# %%
data1.head()
# Out:
#    Ozone  Solar.R  winds  Month  Day  Year  Temp Weather
# 0   41.0    190.0    7.4    5.0    1  2010    67       S
# 1   36.0    118.0    8.0    5.0    2  2010    72       C
# 2   12.0    149.0   12.6    5.0    3  2010    74      PS
# 3   18.0    313.0   11.5    5.0    4  2010    62       S
# 4    NaN      NaN   14.3    5.0    5  2010    56       S

# %%
#print correlation coefficients for all the above column
data1_numeric.corr()
# Out:
#             Unnamed: 0     Ozone   Solar.R       Day
# Unnamed: 0    1.000000  0.124515 -0.109520  0.216219
# Ozone         0.124515  1.000000  0.348642 -0.035055
# Solar.R      -0.109520  0.348642  1.000000 -0.154212
# Day           0.216219 -0.035055 -0.154212  1.000000

# %% [markdown]
# ###### observations
# -the highest corrleaation strength is observed between Ozone and temperature (0.5977087)
# -the highest corrleaation strength is observed between Ozone and wind(-0.523738)
# -the highest corrleaation strength is observed between wind and temp (0-441228)
# -the highest corrleaation strength is observed between solar and wind

# %%
sns.pairplot(data1_numeric)

# %% [markdown]
# Transformations

# %%
#creating dummy variable for weather columns
data2=pd.get_dummies(data1,columns=['Month','Weather'])
data2
# Out:
#      Ozone  Solar.R  winds  Day  Year  Temp  Month_5.0  Month_6.0  Month_7.0  \
# 0     41.0    190.0    7.4    1  2010    67       True      False      False
# 1     36.0    118.0    8.0    2  2010    72       True      False      False
# 2     12.0    149.0   12.6    3  2010    74       True      False      False
# 3     18.0    313.0   11.5    4  2010    62       True      False      False
# 4      NaN      NaN   14.3    5  2010    56       True      False      False
# ..     ...      ...    ...  ...   ...   ...        ...        ...        ...
# 152   20.0    223.0   11.5   30  2010    68      False      False      False
# 153   41.0    190.0    7.4    1  2010    67       True      False      False
# 154   30.0    193.0    6.9   26  2010    70      False      False      False
# 155    NaN    145.0   13.2   27  2010    77      False      False      False
# 157   18.0    131.0    8.0   29  2010    76      False      False      False
#
#      Month_8.0  Month_9.0  Weather_C  Weather_PS  Weather_S
# 0        False      False      False       False       True
# 1        False      False       True       False      False
# 2        False      False      False        True      False
# 3        False      False      False       False       True
# 4        False      False      False       False       True
# ..         ...        ...        ...         ...        ...
# 152      False       True      False       False       True
# 153      False      False       True       False      False
# 154      False       True      False        True      False
# 155      False       True      False       False       True
# 157      False       True       True       False      False
#
# [157 rows x 14 columns]

# %%
data1_numeric.values
# Out:
# array([[  1.,  41., 190.,   1.],
#        [  2.,  36., 118.,   2.],
#        [  3.,  12., 149.,   3.],
#        [  4.,  18., 313.,   4.],
#        [  5.,  nan,  nan,   5.],
#        [  6.,  28.,  nan,   6.],
#        [  7.,  23., 299.,   7.],
#        [  8.,  19.,  99.,   8.],
#        [  9.,   8.,  19.,   9.],
#        [ 10.,  nan, 194.,  10.],
#        [ 11.,   7.,  nan,  11.],
#        [ 12.,  16., 256.,  12.],
#        [ 13.,  11., 290.,  13.],
#        [ 14.,  14., 274.,  14.],
#        [ 15.,  18.,  65.,  15.],
#        [ 16.,  14., 334.,  16.],
#        [ 17.,  34., 307.,  17.],
#        [ 18.,   6.,  78.,  18.],
#        [ 19.,  30., 322.,  19.],
#        [ 20.,  11.,  44.,  20.],
#        [ 21.,   1.,   8.,  21.],
#        [ 22.,  11., 320.,  22.],
#        [ 23.,   4.,  25.,  23.],
#        [ 24.,  32.,  92.,  24.],
#        [ 25.,  nan,  66.,  25.],
#        [ 26.,  nan, 266.,  26.],
#        [ 27.,  nan,  nan,  27.],
#        [ 28.,  23.,  13.,  28.],
#        [ 29.,  45., 252.,  29.],
#        [ 30., 115., 223.,  30.],
#        [ 31.,  37., 279.,  31.],
#        [ 32.,  nan, 286.,   1.],
#        [ 33.,  nan, 287.,   2.],
#        [ 34.,  nan, 242.,   3.],
#        [ 35.,  nan, 186.,   4.],
#        [ 36.,  nan, 220.,   5.],
#        [ 37.,  nan, 264.,   6.],
#        [ 38.,  29., 127.,   7.],
#        [ 39.,  nan, 273.,   8.],
#        [ 40.,  71., 291.,   9.],
#        [ 41.,  39., 323.,  10.],
#        [ 42.,  nan, 259.,  11.],
#        [ 43.,  nan, 250.,  12.],
#        [ 44.,  23., 148.,  13.],
#        [ 45.,  nan, 332.,  14.],
#        [ 46.,  nan, 322.,  15.],
#        [ 47.,  21., 191.,  16.],
#        [ 48.,  37., 284.,  17.],
#        [ 49.,  20.,  37.,  18.],
#        [ 50.,  12., 120.,  19.],
#        [ 51.,  13., 137.,  20.],
#        [ 52.,  nan, 150.,  21.],
#        [ 53.,  nan,  59.,  22.],
#        [ 54.,  nan,  91.,  23.],
#        [ 55.,  nan, 250.,  24.],
#        [ 56.,  nan, 135.,  25.],
#        [ 57.,  nan, 127.,  26.],
#        [ 58.,  nan,  47.,  27.],
#        [ 59.,  nan,  98.,  28.],
#        [ 60.,  nan,  31.,  29.],
#        [ 61.,  nan, 138.,  30.],
#        [ 62., 135., 269.,   1.],
#        [ 63.,  49., 248.,   2.],
#        [ 64.,  32., 236.,   3.],
#        [ 65.,  nan, 101.,   4.],
#        [ 66.,  64., 175.,   5.],
#        [ 67.,  40., 314.,   6.],
#        [ 68.,  77., 276.,   7.],
#        [ 69.,  97., 267.,   8.],
#        [ 70.,  97., 272.,   9.],
#        [ 71.,  85., 175.,  10.],
#        [ 72.,  nan, 139.,  11.],
#        [ 73.,  10., 264.,  12.],
#        [ 74.,  27., 175.,  13.],
#        [ 75.,  nan, 291.,  14.],
#        [ 76.,   7.,  48.,  15.],
#        [ 77.,  48., 260.,  16.],
#        [ 78.,  35., 274.,  17.],
#        [ 79.,  61., 285.,  18.],
#        [ 80.,  79., 187.,  19.],
#        [ 81.,  63., 220.,  20.],
#        [ 82.,  16.,   7.,  21.],
#        [ 83.,  nan, 258.,  22.],
#        [ 84.,  nan, 295.,  23.],
#        [ 85.,  80., 294.,  24.],
#        [ 86., 108., 223.,  25.],
#        [ 87.,  20.,  81.,  26.],
#        [ 88.,  52.,  82.,  27.],
#        [ 89.,  82., 213.,  28.],
#        [ 90.,  50., 275.,  29.],
#        [ 91.,  64., 253.,  30.],
#        [ 92.,  59., 254.,  31.],
#        [ 93.,  39.,  83.,   1.],
#        [ 94.,   9.,  24.,   2.],
#        [ 95.,  16.,  77.,   3.],
#        [ 96.,  78.,  nan,   4.],
#        [ 97.,  35.,  nan,   5.],
#        [ 98.,  66.,  nan,   6.],
#        [ 99., 122., 255.,   7.],
#        [100.,  89., 229.,   8.],
#        [101., 110., 207.,   9.],
#        [102.,  nan, 222.,  10.],
#        [103.,  nan, 137.,  11.],
#        [104.,  44., 192.,  12.],
#        [105.,  28., 273.,  13.],
#        [106.,  65., 157.,  14.],
#        [107.,  nan,  64.,  15.],
#        [108.,  22.,  71.,  16.],
#        [109.,  59.,  51.,  17.],
#        [110.,  23., 115.,  18.],
#        [111.,  31., 244.,  19.],
#        [112.,  44., 190.,  20.],
#        [113.,  21., 259.,  21.],
#        [114.,   9.,  36.,  22.],
#        [115.,  nan, 255.,  23.],
#        [116.,  45., 212.,  24.],
#        [117., 168., 238.,  25.],
#        [118.,  73., 215.,  26.],
#        [119.,  nan, 153.,  27.],
#        [120.,  76., 203.,  28.],
#        [121., 118., 225.,  29.],
#        [122.,  84., 237.,  30.],
#        [123.,  85., 188.,  31.],
#        [124.,  96., 167.,   1.],
#        [125.,  78., 197.,   2.],
#        [126.,  73., 183.,   3.],
#        [127.,  91., 189.,   4.],
#        [128.,  47.,  95.,   5.],
#        [129.,  32.,  92.,   6.],
#        [130.,  20., 252.,   7.],
#        [131.,  23., 220.,   8.],
#        [132.,  21., 230.,   9.],
#        [133.,  24., 259.,  10.],
#        [134.,  44., 236.,  11.],
#        [135.,  21., 259.,  12.],
#        [136.,  28., 238.,  13.],
#        [137.,   9.,  24.,  14.],
#        [138.,  13., 112.,  15.],
#        [139.,  46., 237.,  16.],
#        [140.,  18., 224.,  17.],
#        [141.,  13.,  27.,  18.],
#        [142.,  24., 238.,  19.],
#        [143.,  16., 201.,  20.],
#        [144.,  13., 238.,  21.],
#        [145.,  23.,  14.,  22.],
#        [146.,  36., 139.,  23.],
#        [147.,   7.,  49.,  24.],
#        [148.,  14.,  20.,  25.],
#        [149.,  30., 193.,  26.],
#        [150.,  nan, 145.,  27.],
#        [151.,  14., 191.,  28.],
#        [152.,  18., 131.,  29.],
#        [153.,  20., 223.,  30.],
#        [154.,  41., 190.,   1.],
#        [155.,  30., 193.,  26.],
#        [156.,  nan, 145.,  27.],
#        [157.,  14., 191.,  28.],
#        [158.,  18., 131.,  29.]])

# %%
#Normalization of the data
from numpy import set_printoptions
from sklearn.preprocessing import MinMaxScaler

array=data1_numeric.values

scaler=MinMaxScaler(feature_range=(0,1))
rescaledX=scaler.fit_transform(array)

set_printoptions(precision=2)
print(rescaledX[0:10,:])
# Out:
# [[0.   0.24 0.56 0.  ]
#  [0.01 0.21 0.34 0.03]
#  [0.01 0.07 0.43 0.07]
#  [0.02 0.1  0.94 0.1 ]
#  [0.03  nan  nan 0.13]
#  [0.03 0.16  nan 0.17]
#  [0.04 0.13 0.89 0.2 ]
#  [0.04 0.11 0.28 0.23]
#  [0.05 0.04 0.04 0.27]
#  [0.06  nan 0.57 0.3 ]]
